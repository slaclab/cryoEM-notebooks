# %% [markdown]
# Some simple interactive graphing examples that might be useful

# %% [markdown]
# # Visualize multidimensional data
# view 3D scatter plot with matplotlib. Not interactive...

# %%
# %matplotlib inline
import sys
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
from matplotlib import gridspec
from matplotlib.ticker import MultipleLocator
sys.path.append('../src/')
import dataviz

# %%
data = np.random.random((3, 10000))

# %%
data.shape
# Out:
# (3, 10000)

# %%
dataviz.biplots(data.T, prj2 = np.exp(data.T),  figsize=4, n=3, nbins=20, show_histo=True)

# %%
dataviz.biplots(data.T, prj2 = np.exp(data.T),  figsize=4, n=3, nbins=20, show_histo=True, c='scatter')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /opt/rh/rh-python36/root/usr/lib64/python3.6/site-packages/matplotlib/axes/_axes.py in _parse_scatter_color_args(c, edgecolors, kwargs, xshape, yshape, get_next_color_func)
#    4276             try:  # Then is 'c' acceptable as PathCollection facecolors?
# -> 4277                 colors = mcolors.to_rgba_array(c)
#    4278                 n_elem = colors.shape[0]
#
# /opt/rh/rh-python36/root/usr/lib64/python3.6/site-packages/matplotlib/colors.py in to_rgba_array(c, alpha)
#     285     for i, cc in enumerate(c):
# --> 286         result[i] = to_rgba(cc, alpha)
#     287     return result
#
# /opt/rh/rh-python36/root/usr/lib64/python3.6/site-packages/matplotlib/colors.py in to_rgba(c, alpha)
#     176     if rgba is None:  # Suppress exception chaining of cache lookup failure.
# --> 177         rgba = _to_rgba_no_colorcycle(c, alpha)
#     178         try:
#
# /opt/rh/rh-python36/root/usr/lib64/python3.6/site-packages/matplotlib/colors.py in _to_rgba_no_colorcycle(c, alpha)
#     230             pass
# --> 231         raise ValueError("Invalid RGBA argument: {!r}".format(orig_c))
#     232     # tuple color.
#
# ValueError: Invalid RGBA argument: 's'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-27-e5317af65ec5> in <module>
# ----> 1 dataviz.biplots(data.T, prj2 = np.exp(data.T),  figsize=4, n=3, nbins=20, show_histo=True, c='scatter')
#
# /gpfs/slac/cryo/fs1/u/fpoitevi/slaclab/cryoEM-notebooks/src/dataviz.py in biplots(prj, prj2, n, plottype, nbins, figsize, c, show_histo, figname)
#      61         for j in np.arange(0,ncol,1):
#      62             if(i<j):
# ---> 63                 ax = biplot_axis(n,i,j,gs,fig,labels,Ax=prj[:,j],Ay=prj[:,i],c=c,cmap=cmap,nbins=nbins,majortick=0.2,minortick=0.1,linewidth=2.5,plottype=plottype)
#      64             elif(i==j):
#      65                 if(show_histo):
#
# /gpfs/slac/cryo/fs1/u/fpoitevi/slaclab/cryoEM-notebooks/src/dataviz.py in biplot_axis(n, i, j, gs, fig, labels, Ax, Ay, c, cmap, nbins, majortick, minortick, linewidth, plottype)
#     138         ax.tick_params(axis='both', which='both',bottom=False,top=False,left=False,right=False,labelbottom=False,labeltop=False,labelleft=False,labelright=False,labelsize='large')
#     139     if(plottype == 'scatter'):
# --> 140         ax.scatter(Ax, Ay, c=c, cmap=cmap)
#     141     else:
#     142         ax.hexbin(Ax, Ay, gridsize=nbins, cmap=cmap, mincnt=1)
#
# /opt/rh/rh-python36/root/usr/lib64/python3.6/site-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1587     def inner(ax, *args, data=None, **kwargs):
#    1588         if data is None:
# -> 1589             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1590
#    1591         bound = new_sig.bind(ax, *args, **kwargs)
#
# /opt/rh/rh-python36/root/usr/lib64/python3.6/site-packages/matplotlib/axes/_axes.py in scatter(self, x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, verts, edgecolors, plotnonfinite, **kwargs)
#    4444             self._parse_scatter_color_args(
#    4445                 c, edgecolors, kwargs, xshape, yshape,
# -> 4446                 get_next_color_func=self._get_patches_for_fill.get_next_color)
#    4447
#    4448         if plotnonfinite and colors is None:
#
# /opt/rh/rh-python36/root/usr/lib64/python3.6/site-packages/matplotlib/axes/_axes.py in _parse_scatter_color_args(c, edgecolors, kwargs, xshape, yshape, get_next_color_func)
#    4296                         "'c' argument must be a mpl color, a sequence of mpl "
#    4297                         "colors or a sequence of numbers, not {}."
# -> 4298                             .format(c)  # note: could be long depending on c
#    4299                     )
#    4300         else:
#
# ValueError: 'c' argument must be a mpl color, a sequence of mpl colors or a sequence of numbers, not scatter.

# %%
#

# %%
fig = plt.figure(figsize=(6,6))
ax = fig.add_subplot(111, projection='3d')
ax.scatter(x, y, z, c=x*y*z, marker='.')
ax.set_xlabel('X Label')
ax.set_ylabel('Y Label')
ax.set_zlabel('Z Label')
plt.tight_layout()
plt.show()

# %% [markdown]
# # Visualize density maps
# Might be interesting to have the following libraries:
# - [Mayavi](http://docs.enthought.com/mayavi/mayavi/auto/example_chemistry.html#example-chemistry)
#
# Works nicely: view a volume render of some data with ipyvolume

# %%
import ipyvolume as ipv
import numpy as np
x, y, z = np.random.random((3, 10000))
v = np.random.random((50,10000))
ipv.quickscatter(x, y, z, size=v, marker="sphere")

# %% [markdown]
# # Visualize structural models
# Use NGL view to view a structure

# %%
import nglview as nv
import pytraj as pt
traj = pt.load('./material/simple_data/3pqr.pdb')
view = nv.show_pytraj(traj)
view
