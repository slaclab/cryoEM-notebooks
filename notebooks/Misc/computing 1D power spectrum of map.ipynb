# %% [markdown]
# ### Load libraries

# %%
# %matplotlib inline
from matplotlib import pyplot as plt
import numpy as np
import sys
sys.path.append('/Users/fpoitevi/gdrive/cryoEM/Methods/cryoEM-notebooks/src/')
import dataviz, mrcutils
# uncomment next lines to reload libraries without having to restart the kernel
from importlib import reload
reload(dataviz)
reload(mrcutils)
# Out:
# <module 'mrcutils' from '/Users/fpoitevi/gdrive/cryoEM/Methods/cryoEM-notebooks/src/mrcutils.py'>

# %% [markdown]
# ### Give path to mrc file

# %%
#mrc_file = '/Users/fpoitevi/gdrive/cryoEM/Methods/cryoEM-notebooks/notebooks/Material/simple_data/cryosparc_P11_J24_009_volume_map_sharp.mrc'
mrc_file = '/Users/fpoitevi/gdrive/cryoEM/Methods/cryoEM-notebooks/notebooks/Material/simple_data/cryosparc_P11_J24_009_volume_map.mrc'

# %% [markdown]
# ### Load map (and display to check it's good)

# %%
initial_psize    = 1.16
downsample_level = 1
psize = downsample_level*initial_psize
data = mrcutils.mrc2data(mrc_file)[::downsample_level,::downsample_level,::downsample_level]

# %%
mrcutils.showdata(data, level=[-1,3])

# %% [markdown]
# ### Compute its power spectrum (and display to check it's good)

# %%
data_psd = mrcutils.data2psd(data, log=False)

# %%
mrcutils.showdata(np.log(data_psd),level=[-1,2])

# %% [markdown]
# ### Compute 1D PSD from 3D PSD

# %%
freq, psd_1d = mrcutils.plot_rasp(data_psd, psize=psize, offset=1e-6)
# Out:
# > pixel size: 1.16
